# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ny = int(1801/2)
nx = int(1350/2)

# %%
h = np.loadtxt('/home/tsunamilab/Downloads/tlab2D (1)',delimiter=',',skiprows=1).reshape((ny,nx))

# %%
plt.pcolormesh(h,cmap=plt.cm.jet)
plt.colorbar()

# %%
t = np.loadtxt('/home/tsunamilab/Downloads/tlab2D (2)',delimiter=',',skiprows=1).reshape((ny,nx))

# %%
plt.pcolormesh(h,vmax=3)
plt.contour(t/60/60,range(7),colors='r',linewidths=[0.4,0.4,0.4,0.4,0.4,0.4,0.0])
plt.colorbar()
