# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ny = int(1401/4)
nx = int(3101/4)

# %%
hlast = np.loadtxt('../tsunamilab/tlab2D (4)',delimiter=',',skiprows=1).reshape((ny,nx))
hmax= np.loadtxt('../tsunamilab/tlab2D (5)',delimiter=',',skiprows=1).reshape((ny,nx))
arrival= np.loadtxt('../tsunamilab/tlab2D (6)',delimiter=',',skiprows=1).reshape((ny,nx))

# %%
k = 3
plt.figure(figsize=(6*k,2*k))
plt.pcolormesh(hmax,vmin=0,vmax=1)
plt.colorbar()
c = plt.contour(arrival/60/60,colors='w',linewidths=0.4)
plt.contour(arrival/60/60,range(22),colors='w',linewidths=0.2)
plt.clabel(c, inline=1, fontsize=10)
ax = plt.gca()
ax.set_aspect(1)
