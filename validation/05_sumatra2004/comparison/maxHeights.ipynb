# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
z = np.loadtxt('/home/tsunamilab/Downloads/tlab2D (79)',delimiter=',',skiprows=1).reshape((960,2159))

# %%
plt.figure(figsize=(12,6))
plt.pcolormesh(z[::1,::1],vmax=0.1,vmin=0.0,cmap=plt.cm.viridis)
plt.colorbar()

# %% [markdown]
# # Arrival times

# %%
T = np.loadtxt('/home/tsunamilab/Downloads/tlab2D (80)',delimiter=',',skiprows=1).reshape((960,2159))

# %%
plt.figure(figsize=(12,6))
plt.pcolormesh(T/60/60)
plt.colorbar()

# %%
bathymetry = np.loadtxt('../data/bathymetry')

# %%
maskedT = np.ma.masked_where(bathymetry<-0, T/60/60)

# %%
plt.figure(figsize=(12,6))
plt.pcolormesh(z,vmax=0.2,vmin=0.0,cmap=plt.cm.jet)
plt.colorbar()
c = plt.contour(maskedT, range(30), colors='k',linewidths=0.5)
# plt.xlim(100,1750)
# plt.gca().set_aspect(1)
# plt.savefig('asdf.png',dpi=300)
